# %%
print("Jupyter is ready for professional workflow!")
# Out:
# Jupyter is ready for professional workflow!

# %% [markdown]
# # Data Analysis Template
#
# This notebook provides a structured workflow for performing data analysis using Python.
# It includes:
# - Data import and exploration
# - Data cleaning and transformation
# - Visualization
# - Statistical summary
#
# **Author:** Your Name
# **Date:** YYYY-MM-DD

# %%
# Import essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
sns.set(style="whitegrid")

# %%
# --- Markdown Cell ---
# # Data Analysis Template (Offline-Ready)
# This notebook demonstrates a workflow using built-in datasets from scikit-learn.
# It covers:
# - Loading a dataset (offline)
# - Data exploration
# - Basic visualization
# - Statistical summary

# ## Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

sns.set(style="whitegrid")

# ## Load Built-in Dataset (Iris)
iris = datasets.load_iris(as_frame=True)
df = iris.frame

# ## Data Overview
print("Shape:", df.shape)
display(df.head())
display(df.describe())

# ## Visualization
sns.pairplot(df, hue="target", diag_kind="kde")
plt.suptitle("Iris Dataset Pairplot", y=1.02)
plt.show()
# Out:
# Shape: (150, 5)
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# ...

# %%
# Summary statistics
print("Dataset shape:", df.shape)
print("\nDataset info:")
print(df.info())

# Descriptive statistics
df.describe()
# Out:
# Dataset shape: (150, 5)
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# ...

# %%
# Example cleaning steps
# df = df.dropna()
# df = df[df['Value'] > 0]
# df['Category'] = df['Category'].str.strip()
print("Data cleaning steps done (if needed).")
# Out:
# Data cleaning steps done (if needed).

# %%
# Simple visualization example
sns.barplot(x="Category", y="Value", data=df, estimator=np.mean)
plt.title("Average Value by Category")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Simple visualization example
# ----> 2 sns.barplot(x="Category", y="Value", data=df, estimator=np.mean)
#       3 plt.title("Average Value by Category")
#       4 plt.show()
#
# File ~/html5up-paradigm-shift/.venv/lib/python3.13/site-packages/seaborn/categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
# ...

# %% [markdown]
# ## Summary & Next Steps
# - Dataset loaded and analyzed.
# - Visualization created for quick insights.
# - Next: Add your own dataset and repeat the steps.
